# %% [markdown]
# ## 作業1
# 1. Suicide Rates Overview 1985 to 2016。這份資料集很重要，因為可以讓人們了解自殺率的趨勢變化。
# 2. 這份資料集的來源十分可靠，大多取自世界級的組織，例如United Nations Development Program. (2018)、World Bank. (2018)、World Health Organization. (2018)等等。
# 3. 此為需要檢視欄欄位意義以及名稱的結構化資料。
# 4. 可觀察自殺率的趨勢，是下降抑或上增；也可檢視不同地區的自殺率，進一步探討為何某些地區自殺率較高？跟GDP有無關係？

# %% [markdown]
# ## 作業2
# 1. 運用大數據分析搭車需求高的地點，可使司機先行抵達候車，減少乘客等待時間，亦可達增加載客次數，降低空車率的目的，以提升整體營收。
# 2. 可以蒐集歷史乘車紀錄，包括搭乘時段、時間、人數等，藉由大數據分析預測，可以製作動態缺車預測地圖，開放給司機及民眾使用。
# 3. 結構性資料。
# 4. 檢視乘車地點時段之預測的精準度之外，最重要的是空車率有無降低？整體營收有無提高？

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, y_hat):
    mse =  sum(pow(y-y_hat,2))/len(y)
    return mse

# %%
def mean_absolute_error(y, yp):
    mae = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 194.517
# The Mean absolute error is 11.167
